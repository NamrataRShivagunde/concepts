# %% [markdown]
# Reference: Python for Data Science Cheat Sheet Matplotlib
# www.datacamp.com

# %%
#1 Prepare the data
import numpy as np
x = np.linspace(0,10,100)
y = np.cos(x)
z = np.sin(x)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y
# Out:
# array([ 1.        ,  0.99490282,  0.97966323,  0.95443659,  0.91948007,
#         0.87515004,  0.8218984 ,  0.76026803,  0.69088721,  0.61446323,
#         0.53177518,  0.44366602,  0.35103397,  0.25482335,  0.15601496,
#         0.0556161 , -0.04534973, -0.14585325, -0.24486989, -0.34139023,
#        -0.43443032, -0.52304166, -0.60632092, -0.68341913, -0.75355031,
#        -0.81599952, -0.87013012, -0.91539031, -0.95131866, -0.97754893,
#        -0.9938137 , -0.99994717, -0.9958868 , -0.981674  , -0.95745366,
#        -0.92347268, -0.88007748, -0.82771044, -0.76690542, -0.69828229,
#        -0.6225406 , -0.54045251, -0.45285485, -0.36064061, -0.26474988,
#        -0.16616018, -0.06587659,  0.03507857,  0.13567613,  0.23489055,
#         0.33171042,  0.4251487 ,  0.51425287,  0.59811455,  0.67587883,
#         0.74675295,  0.8100144 ,  0.86501827,  0.91120382,  0.94810022,
#         0.97533134,  0.99261957,  0.99978867,  0.99676556,  0.98358105,
# ...

# %%
z
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %%
data = 2*np.random.random((10,10))

# %%
data
# Out:
# array([[1.98567843, 1.92982547, 1.53512672, 1.12561711, 0.0513074 ,
#         0.31093339, 1.25922024, 0.92612633, 1.59393585, 0.24582782],
#        [1.41188707, 0.26811683, 0.67562235, 0.58178624, 1.83440473,
#         1.940906  , 0.54868549, 0.43344777, 0.31338959, 0.85581008],
#        [0.5240163 , 0.9836504 , 0.25093464, 1.65830777, 0.21667046,
#         0.05382437, 0.92769462, 0.78394122, 1.12801168, 1.89174133],
#        [0.63860007, 1.01292635, 0.20189824, 1.3379454 , 1.0510506 ,
#         1.64002993, 0.90906062, 1.95780635, 1.17742776, 1.16126208],
#        [0.16095201, 0.9646757 , 0.68770876, 0.30262503, 0.83179104,
#         0.18283946, 1.87090108, 0.04386699, 1.26888647, 0.75701027],
#        [0.55167862, 1.94936096, 1.02233643, 0.02194635, 1.79931841,
#         1.72897528, 0.10016099, 0.70980804, 0.12636396, 1.07341823],
#        [1.27877324, 1.21872777, 0.91148222, 1.76721826, 0.99229095,
#         0.17963104, 0.62349933, 0.87440166, 0.21857855, 0.51870606],
# ...

# %%
data2 = 3*np.random.random((10,10))

# %%
data2
# Out:
# array([[2.34574594, 1.12931455, 2.90998265, 2.07230848, 1.5423324 ,
#         0.76346934, 0.96663231, 2.23150249, 2.93269058, 0.84615133],
#        [0.39481206, 1.49870076, 2.29529327, 2.14285226, 1.36640206,
#         1.55733385, 0.96713088, 0.89897687, 2.17586627, 0.52410724],
#        [2.53231023, 2.34741269, 1.31657914, 0.9045086 , 0.59938527,
#         2.47756773, 2.54401683, 0.67346799, 2.57162668, 1.4794317 ],
#        [2.7360535 , 1.52815153, 2.14029052, 1.68356634, 0.90103129,
#         1.66709812, 0.23862345, 0.79491254, 2.95429873, 1.19528296],
#        [1.27948611, 1.45631089, 2.09456093, 2.32582041, 2.79716819,
#         0.72810001, 1.3200582 , 0.31319703, 0.08796547, 2.36391818],
#        [0.62673073, 1.71175056, 0.63716503, 0.23403684, 1.42906271,
#         0.52054125, 1.85992813, 1.11105581, 0.03889321, 0.90665519],
#        [0.05018493, 1.51646841, 0.03781124, 2.77673967, 0.55585253,
#         1.87676102, 0.43536428, 2.03619079, 1.00353829, 1.24983712],
# ...

# %%
Y,X = np.mgrid[-3:3:100j, -3:3:100j]

# %%
X
# Out:
# array([[-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        ...,
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ]])

# %%
Y
# Out:
# array([[-3.        , -3.        , -3.        , ..., -3.        ,
#         -3.        , -3.        ],
#        [-2.93939394, -2.93939394, -2.93939394, ..., -2.93939394,
#         -2.93939394, -2.93939394],
#        [-2.87878788, -2.87878788, -2.87878788, ..., -2.87878788,
#         -2.87878788, -2.87878788],
#        ...,
#        [ 2.87878788,  2.87878788,  2.87878788, ...,  2.87878788,
#          2.87878788,  2.87878788],
#        [ 2.93939394,  2.93939394,  2.93939394, ...,  2.93939394,
#          2.93939394,  2.93939394],
#        [ 3.        ,  3.        ,  3.        , ...,  3.        ,
#          3.        ,  3.        ]])

# %%
U = -1-X**2+Y

# %%
U
# Out:
# array([[-13.        , -12.64003673, -12.28741965, ..., -12.28741965,
#         -12.64003673, -13.        ],
#        [-12.93939394, -12.57943067, -12.22681359, ..., -12.22681359,
#         -12.57943067, -12.93939394],
#        [-12.87878788, -12.51882461, -12.16620753, ..., -12.16620753,
#         -12.51882461, -12.87878788],
#        ...,
#        [ -7.12121212,  -6.76124885,  -6.40863177, ...,  -6.40863177,
#          -6.76124885,  -7.12121212],
#        [ -7.06060606,  -6.70064279,  -6.34802571, ...,  -6.34802571,
#          -6.70064279,  -7.06060606],
#        [ -7.        ,  -6.64003673,  -6.28741965, ...,  -6.28741965,
#          -6.64003673,  -7.        ]])

# %%
V = 1+X-Y**2

# %%
V
# Out:
# array([[-11.        , -10.93939394, -10.87878788, ...,  -5.12121212,
#          -5.06060606,  -5.        ],
#        [-10.64003673, -10.57943067, -10.51882461, ...,  -4.76124885,
#          -4.70064279,  -4.64003673],
#        [-10.28741965, -10.22681359, -10.16620753, ...,  -4.40863177,
#          -4.34802571,  -4.28741965],
#        ...,
#        [-10.28741965, -10.22681359, -10.16620753, ...,  -4.40863177,
#          -4.34802571,  -4.28741965],
#        [-10.64003673, -10.57943067, -10.51882461, ...,  -4.76124885,
#          -4.70064279,  -4.64003673],
#        [-11.        , -10.93939394, -10.87878788, ...,  -5.12121212,
#          -5.06060606,  -5.        ]])

# %%
#2 Create plot
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
fig2 = plt.figure(figsize=plt.figaspect(2.0))

# %%
fig.add_axes()

# %%
fig

# %%
ax1 = fig.add_subplot(221)

# %%
ax1

# %%
fig

# %%
ax3= fig.add_subplot(212)

# %%
ax3

# %%
fig

# %%
fig3, axes = plt.subplots(nrows = 2,ncols =2)

# %%
fig4 ,axes2 = plt.subplots(ncols = 3)

# %%
#3plotting routines
lines = plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.bar([1,2,3],[3,4,5])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh([1,2,3],[3,4,5])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.axhline(0.45)

# %%
plt.axvline(0.65)

# %%
plt.fill(x,y, color = 'blue')

# %%
plt.fill_between(x,y, color ='green')

# %%
fig ,ax =plt.subplots()

# %%
plt.arrow(0,0,0.5,0.5)

# %%
fig3, axes = plt.subplots(nrows = 2,ncols =2)

# %%
axes[0,1].arrow(0,0,0.5,0.5)

# %%
fig3

# %%
axes[1,1].quiver(y,z)

# %%
fig3

# %%
axes[1,0].streamplot(X,Y,U,V)

# %%
fig3

# %%
ax1.hist(y)
# Out:
# (array([26.,  8.,  7.,  6.,  6.,  6.,  6.,  7.,  8., 20.]),
#  array([-9.99947166e-01, -7.99952450e-01, -5.99957733e-01, -3.99963016e-01,
#         -1.99968300e-01,  2.64169119e-05,  2.00021134e-01,  4.00015850e-01,
#          6.00010567e-01,  8.00005283e-01,  1.00000000e+00]),
#  <a list of 10 Patch objects>)

# %%
ax3.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2f5a18fbfd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2f5a17c84e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2f5a191b8d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2f5a17c81d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2f5a17d66d8>],
#  'means': []}

# %%
fig, ax1
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x2f59f2992e8>)

# %%
fig4

# %%
axes2
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002F5A02024E0>,
# ...
#       dtype=object)

# %%
CS = plt.contour(Y,X,U)

# %%
import matplotlib.pyplot as plt
x =[1,2,3,4]
y = [10,20,30,25]
fig = plt.figure()

# %%
ax = fig.add_subplot(111)

# %%
fig

# %%
ax.plot(x,y, color = 'lightblue')

# %%
fig

# %%
ax.plot(x,y,color = 'lightblue', linewidth =7)

# %%
fig

# %%
ax.scatter([2,4,6],[5,15,25], color = 'darkgreen', marker ='^')

# %%
fig

# %%
ax.set_xlim(1,7)
# Out:
# (1, 7)

# %%
fig

# %%
plt.savefig('foo.png')

# %%
plt.show()

# %%
#customize plot
ax.plot(x,y, alpha =0.4)

# %%
fig

# %%
ax.plot(x,y, c='k')

# %%
fig

# %%
fig,ax = plt.subplots()

# %%
ax.scatter(x,y, marker= ",")

# %%
fig

# %%
fig,ax = plt.subplots()

# %%
ax.plot(x,y, marker = ',')

# %%
fig

# %%
plt.plot(x,y, linewidth = 4.0)

# %%
fig

# %%
plt.plot(x,y, ls = 'solid')

# %%
plt.plot(x,y, ls = '--')

# %%
plt.plot(x,y, '*', x*2,y*2,'-.')

# %%
plt.setp(lines, color='r', linewidth =4.0)
# Out:
# [None, None]

# %%
fig

# %%
ax.text(1,-2.1,'Example Graph', style = 'italic')
# Out:
# Text(1, -2.1, 'Example Graph')

# %%
ax

# %%
plt.title('Example', fontsize =20)
# Out:
# Text(0.5, 1.0, 'Example')

# %%
ax.margins(x=0.0,y=0.1)

# %%
fig

# %%
ax.axis('equal')
# Out:
# (1.0, 4.0, 8.0, 32.0)

# %%
fig

# %%
ax.set(xlim =[0,10], ylim =[5,35])
# Out:
# [(5, 35), (0, 10)]

# %%
fig

# %%
ax.set(title = 'Graph A', ylabel = 'y axis', xlabel = 'x axis')
# Out:
# [Text(3.1999999999999993, 0.5, 'y axis'),
#  Text(0.5, 39.660799999999995, 'x axis'),
#  Text(0.5, 1, 'Graph A')]

# %%
fig

# %%
ax.legend(loc = 'best')
# Out:
# No handles with labels found to put in legend.

# %%
ax.xaxis.set(ticks = range(1,10), ticklabels = [3,0,0,"f"])
# Out:
# [[<matplotlib.axis.XTick at 0x2f5a19edfd0>,
# ...
#  [Text(1, 0, '3'), Text(2, 0, '0'), Text(3, 0, '0'), Text(4, 0, 'f')]]

# %%
fig

# %%
ax.tick_params(axis = 'y',direction ='inout',length =19)

# %%
fig

# %%
fig3

# %%
fig3.subplots_adjust(wspace =0.5,
                    hspace = 0.3,
                    left = 0.125,
                    right = 0.9,
                    top = 0.9,
                    bottom = 0.1)

# %%
fig3

# %%
fig.tight_layout()

# %%
fig

# %%
fig3

# %%
fig3.tight_layout()

# %%
fig3

# %%
ax1

# %%
fig

# %%
ax.spines['top'].set_visible(False)

# %%
fig

# %%
ax.spines['bottom'].set_position(('outward',10))

# %%
fig

# %%
#save plot
plt.savefig('foo.png')

# %%
plt.show()

# %%
#for single plot
#reference:  https://stackoverflow.com/questions/43482191/matplotlib-axes-plot-vs-pyplot-plot 
fig = plt.figure()
plt.plot(data)
fig.show()
# Out:
# C:\Users\namrata\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
line = plt.plot(data)

# %%
ax = plt.axes()
line = ax.plot(data)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
line = ax.plot(data)
