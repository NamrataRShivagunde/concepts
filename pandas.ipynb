# %% [markdown]
# Pandas practice using 'Data Wranging with pandas cheat sheet' from http://pandas.pydata.org/

# %% [markdown]
# Creating Dataframes

# %%
import pandas as pd

# %%
df =pd.DataFrame({"a":[4,5,6], "b":[7,8,9], "c":[10,11,12]})

# %%
df
# Out:
#    a  b   c
# 0  4  7  10
# 1  5  8  11
# 2  6  9  12

# %%
df = pd.DataFrame({"a":[11,12,13],"b":[4,5,6],"c":[7,8,9]}, index = [1,2,3])

# %%
df
# Out:
#     a  b  c
# 1  11  4  7
# 2  12  5  8
# 3  13  6  9

# %%
df = pd.DataFrame([[4,5,6],[7,8,9],[11,12,13]],
                  index = [1,2,3], columns =['a','b','c'])

# %%
df
# Out:
#     a   b   c
# 1   4   5   6
# 2   7   8   9
# 3  11  12  13

# %%
df = pd.DataFrame({"a":[4,5,6],"b":[7,8,9],"c":[10,11,12]},
    index = pd.MultiIndex.from_tuples([('d',1),('d',2),('e',2)],
    names=['n','v']))

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12

# %% [markdown]
# Reshaping data

# %%
a = pd.DataFrame({"a":[1,2,3], "b":[4,5,6], "c":[7,8,9]}, index = ['e','f','g'])

# %%
a
# Out:
#    a  b  c
# e  1  4  7
# f  2  5  8
# g  3  6  9

# %%
ff= a.melt()

# %%
ff
# Out:
#   variable  value
# 0        a      1
# 1        a      2
# 2        a      3
# 3        b      4
# 4        b      5
# 5        b      6
# 6        c      7
# 7        c      8
# 8        c      9

# %%
ff.pivot(columns='variable',values='value')
# Out:
# variable    a    b    c
# 0         1.0  NaN  NaN
# 1         2.0  NaN  NaN
# 2         3.0  NaN  NaN
# 3         NaN  4.0  NaN
# 4         NaN  5.0  NaN
# 5         NaN  6.0  NaN
# 6         NaN  NaN  7.0
# 7         NaN  NaN  8.0
# 8         NaN  NaN  9.0

# %%
b = pd.DataFrame({"a":[10,11,12], "b":[13,14,15], "c":[16,17,18]}, index = ['x','y','z'])

# %%
b
# Out:
#     a   b   c
# x  10  13  16
# y  11  14  17
# z  12  15  18

# %%
#concatination
pd.concat([a,b])
# Out:
#     a   b   c
# e   1   4   7
# f   2   5   8
# g   3   6   9
# x  10  13  16
# y  11  14  17
# z  12  15  18

# %%
pd.concat([a,b],axis=1, sort='False')
# Out:
#      a    b    c     a     b     c
# e  1.0  4.0  7.0   NaN   NaN   NaN
# f  2.0  5.0  8.0   NaN   NaN   NaN
# g  3.0  6.0  9.0   NaN   NaN   NaN
# x  NaN  NaN  NaN  10.0  13.0  16.0
# y  NaN  NaN  NaN  11.0  14.0  17.0
# z  NaN  NaN  NaN  12.0  15.0  18.0

# %%
b = pd.DataFrame({"a":[10,11,12], "b":[13,14,15], "c":[16,17,18]}, index = ['e','f','g'])

# %%
pd.concat([a,b], axis=1)
# Out:
#    a  b  c   a   b   c
# e  1  4  7  10  13  16
# f  2  5  8  11  14  17
# g  3  6  9  12  15  18

# %%
a
# Out:
#    a  b  c
# e  1  4  7
# f  2  5  8
# g  3  6  9

# %%
a.sort_values('c', ascending =False)
# Out:
#    a  b  c
# g  3  6  9
# f  2  5  8
# e  1  4  7

# %%
a.sort_values('c', ascending =True) #a.sort_values('a')
# Out:
#    a  b  c
# e  1  4  7
# f  2  5  8
# g  3  6  9

# %%
a.rename(columns = {'c':'d'})
# Out:
#    a  b  d
# e  1  4  7
# f  2  5  8
# g  3  6  9

# %%
student_data= pd.DataFrame({"Height in cms":[165,160,140,156],"Weight in kgs":[65,70,55,59]}, index = [4,2,1,3])

# %%
student_data
# Out:
#    Height in cms  Weight in kgs
# 4            165             65
# 2            160             70
# 1            140             55
# 3            156             59

# %%
student_data.sort_index()
# Out:
#    Height in cms  Weight in kgs
# 1            140             55
# 2            160             70
# 3            156             59
# 4            165             65

# %%
student_data
# Out:
#    Height in cms  Weight in kgs
# 4            165             65
# 2            160             70
# 1            140             55
# 3            156             59

# %%
student_data.reset_index()
# Out:
#    index  Height in cms  Weight in kgs
# 0      4            165             65
# 1      2            160             70
# 2      1            140             55
# 3      3            156             59

# %%
athlete = ['yes','no','no','no']

# %%
#Adding a column
student_data['Athlete'] = athlete

# %%
student_data
# Out:
#    Height in cms  Weight in kgs Athlete
# 4            165             65     yes
# 2            160             70      no
# 1            140             55      no
# 3            156             59      no

# %%
#drop a column
student_data.drop(columns = ['Athlete'])
# Out:
#    Height in cms  Weight in kgs
# 4            165             65
# 2            160             70
# 1            140             55
# 3            156             59

# %%
student_data
# Out:
#    Height in cms  Weight in kgs Athlete
# 4            165             65     yes
# 2            160             70      no
# 1            140             55      no
# 3            156             59      no

# %%
#add a row
student_data.append({'Height in cms':149, 'Weight in kgs': 48, 'Athlete':'yes'},ignore_index=True)
# Out:
#    Height in cms  Weight in kgs Athlete
# 0            165             65     yes
# 1            160             70      no
# 2            140             55      no
# 3            156             59      no
# 4            149             48     yes

# %%
student_data
# Out:
#    Height in cms  Weight in kgs Athlete
# 4            165             65     yes
# 2            160             70      no
# 1            140             55      no
# 3            156             59      no

# %%
student_data.drop([2])
# Out:
#    Height in cms  Weight in kgs Athlete
# 4            165             65     yes
# 1            140             55      no
# 3            156             59      no

# %%
student_data = student_data.append({'Height in cms':162, 'Weight in kgs': 62, 'Athlete':'yes'},ignore_index=True)

# %%
student_data = student_data.append({'Height in cms':162, 'Weight in kgs': 62, 'Athlete':'yes'},ignore_index=True)
student_data = student_data.append({'Height in cms':170, 'Weight in kgs': 65, 'Athlete':'yes'},ignore_index=True)
student_data = student_data.append({'Height in cms':158, 'Weight in kgs': 56, 'Athlete':'yes'},ignore_index=True)
student_data = student_data.append({'Height in cms':150, 'Weight in kgs': 68, 'Athlete':'no'},ignore_index=True)

# %%
student_data
# Out:
#    Height in cms  Weight in kgs Athlete
# 0            165             65     yes
# 1            160             70      no
# 2            140             55      no
# 3            156             59      no
# 4            162             62     yes
# 5            162             62     yes
# 6            170             65     yes
# 7            158             56     yes
# 8            150             68      no

# %%
#subset observations rows
sd = student_data

# %%
sd[sd.Athlete == 'yes']
# Out:
#    Height in cms  Weight in kgs Athlete
# 0            165             65     yes
# 4            162             62     yes
# 5            162             62     yes
# 6            170             65     yes
# 7            158             56     yes

# %%
sd.drop_duplicates()
# Out:
#    Height in cms  Weight in kgs Athlete
# 0            165             65     yes
# 1            160             70      no
# 2            140             55      no
# 3            156             59      no
# 4            162             62     yes
# 6            170             65     yes
# 7            158             56     yes
# 8            150             68      no

# %%
sd
# Out:
#    Height in cms  Weight in kgs Athlete
# 0            165             65     yes
# 1            160             70      no
# 2            140             55      no
# 3            156             59      no
# 4            162             62     yes
# 5            162             62     yes
# 6            170             65     yes
# 7            158             56     yes
# 8            150             68      no

# %%
sd.head(3)
# Out:
#    Height in cms  Weight in kgs Athlete
# 0            165             65     yes
# 1            160             70      no
# 2            140             55      no

# %%
sd.tail(3)
# Out:
#    Height in cms  Weight in kgs Athlete
# 6            170             65     yes
# 7            158             56     yes
# 8            150             68      no

# %%
sd.sample(frac = 0.5)
# Out:
#    Height in cms  Weight in kgs Athlete
# 2            140             55      no
# 0            165             65     yes
# 6            170             65     yes
# 3            156             59      no

# %%
sd.sample(frac = 0.25)
# Out:
#    Height in cms  Weight in kgs Athlete
# 5            162             62     yes
# 1            160             70      no

# %%
sd.sample(n=3)
# Out:
#    Height in cms  Weight in kgs Athlete
# 0            165             65     yes
# 1            160             70      no
# 5            162             62     yes

# %%
sd.iloc[2:6]
# Out:
#    Height in cms  Weight in kgs Athlete
# 2            140             55      no
# 3            156             59      no
# 4            162             62     yes
# 5            162             62     yes

# %%
sd.nlargest(3,'Height in cms')
# Out:
#    Height in cms  Weight in kgs Athlete
# 6            170             65     yes
# 0            165             65     yes
# 4            162             62     yes

# %%
sd.nsmallest(2, 'Height in cms')
# Out:
#    Height in cms  Weight in kgs Athlete
# 2            140             55      no
# 8            150             68      no

# %%
sd
# Out:
#    Height in cms  Weight in kgs Athlete
# 0            165             65     yes
# 1            160             70      no
# 2            140             55      no
# 3            156             59      no
# 4            162             62     yes
# 5            162             62     yes
# 6            170             65     yes
# 7            158             56     yes
# 8            150             68      no

# %%
sd = student_data.append({'Height in cms':162, 'Weight in kgs': 62, 'Athlete':None },ignore_index=True)

# %%
sd #run append 3 times
# Out:
#    Height in cms  Weight in kgs Athlete
# 0          165.0           65.0     yes
# 1          160.0           70.0      no
# 2          140.0           55.0      no
# 3          156.0           59.0      no
# 4          162.0           62.0     yes
# 5          162.0           62.0     yes
# 6          170.0           65.0     yes
# 7          158.0           56.0     yes
# 8          150.0           68.0      no
# 9          162.0           62.0     NaN

# %%
pd.isnull(sd)
# Out:
#    Height in cms  Weight in kgs  Athlete
# 0          False          False    False
# 1          False          False    False
# 2          False          False    False
# 3          False          False    False
# 4          False          False    False
# 5          False          False    False
# 6          False          False    False
# 7          False          False    False
# 8          False          False    False
# 9          False          False     True

# %%
pd.notnull(sd)
# Out:
#    Height in cms  Weight in kgs  Athlete
# 0           True           True     True
# 1           True           True     True
# 2           True           True     True
# 3           True           True     True
# 4           True           True     True
# 5           True           True     True
# 6           True           True     True
# 7           True           True     True
# 8           True           True     True
# 9           True           True    False

# %%
#subset variables (colums)
sd
# Out:
#    Height in cms  Weight in kgs Athlete
# 0          165.0           65.0     yes
# 1          160.0           70.0      no
# 2          140.0           55.0      no
# 3          156.0           59.0      no
# 4          162.0           62.0     yes
# 5          162.0           62.0     yes
# 6          170.0           65.0     yes
# 7          158.0           56.0     yes
# 8          150.0           68.0      no
# 9          162.0           62.0     NaN

# %%
sd[['Athlete']]
# Out:
#   Athlete
# 0     yes
# 1      no
# 2      no
# 3      no
# 4     yes
# 5     yes
# 6     yes
# 7     yes
# 8      no
# 9     NaN

# %%
sd[['Athlete','Height in cms']]
# Out:
#   Athlete  Height in cms
# 0     yes          165.0
# 1      no          160.0
# 2      no          140.0
# 3      no          156.0
# 4     yes          162.0
# 5     yes          162.0
# 6     yes          170.0
# 7     yes          158.0
# 8      no          150.0
# 9     NaN          162.0

# %%
sd.Athlete
# Out:
# 0    yes
# 1     no
# 2     no
# 3     no
# 4    yes
# 5    yes
# 6    yes
# 7    yes
# 8     no
# 9    NaN
# Name: Athlete, dtype: object

# %%
sd.filter(regex = '^A') #select columns whose first letter is A
# Out:
#   Athlete
# 0     yes
# 1      no
# 2      no
# 3      no
# 4     yes
# 5     yes
# 6     yes
# 7     yes
# 8      no
# 9     NaN

# %%
sd.loc[:,'Height in cms':'Athlete']
# Out:
#    Height in cms  Weight in kgs Athlete
# 0          165.0           65.0     yes
# 1          160.0           70.0      no
# 2          140.0           55.0      no
# 3          156.0           59.0      no
# 4          162.0           62.0     yes
# 5          162.0           62.0     yes
# 6          170.0           65.0     yes
# 7          158.0           56.0     yes
# 8          150.0           68.0      no
# 9          162.0           62.0     NaN

# %%
sd.iloc[:,[0,2]]
# Out:
#    Height in cms Athlete
# 0          165.0     yes
# 1          160.0      no
# 2          140.0      no
# 3          156.0      no
# 4          162.0     yes
# 5          162.0     yes
# 6          170.0     yes
# 7          158.0     yes
# 8          150.0      no
# 9          162.0     NaN

# %%
sd.loc[sd['Height in cms'] <155]
# Out:
#    Height in cms  Weight in kgs Athlete
# 2          140.0           55.0      no
# 8          150.0           68.0      no

# %%
sd.loc[sd['Height in cms']<155 ,['Height in cms','Athlete']]
# Out:
#    Height in cms Athlete
# 2          140.0      no
# 8          150.0      no

# %%
#Summarize data
sd['Athlete'].value_counts()
# Out:
# yes    5
# no     4
# Name: Athlete, dtype: int64

# %%
sd['Height in cms'].value_counts()
# Out:
# 162.0    3
# 150.0    1
# 158.0    1
# 170.0    1
# 156.0    1
# 140.0    1
# 160.0    1
# 165.0    1
# Name: Height in cms, dtype: int64

# %%
len(sd)
# Out:
# 10

# %%
sd['Height in cms'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0    165.0
# 1    160.0
# 2    140.0
# 3    156.0
# 4    162.0
# 5    162.0
# 6    170.0
# 7    158.0
# 8    150.0
# 9    162.0
# Name: Height in cms, dtype: float64>

# %%
sd.describe()
# Out:
#        Height in cms  Weight in kgs
# count      10.000000      10.000000
# mean      158.500000      62.400000
# std         8.396428       4.835057
# min       140.000000      55.000000
# 25%       156.500000      59.750000
# 50%       161.000000      62.000000
# 75%       162.000000      65.000000
# max       170.000000      70.000000

# %%
sd.sum()
# Out:
# Height in cms    1585.0
# Weight in kgs     624.0
# dtype: float64

# %%
sd.min()
# Out:
# Height in cms    140.0
# Weight in kgs     55.0
# dtype: float64

# %%
sd.max()
# Out:
# Height in cms    170.0
# Weight in kgs     70.0
# dtype: float64

# %%
sd.count()
# Out:
# Height in cms    10
# Weight in kgs    10
# Athlete           9
# dtype: int64

# %%
sd.mean()
# Out:
# Height in cms    158.5
# Weight in kgs     62.4
# dtype: float64

# %%
sd.median()
# Out:
# Height in cms    161.0
# Weight in kgs     62.0
# dtype: float64

# %%
sd.quantile([0.25,0.75])
# Out:
#       Height in cms  Weight in kgs
# 0.25          156.5          59.75
# 0.75          162.0          65.00

# %%
sd.var()
# Out:
# Height in cms    70.500000
# Weight in kgs    23.377778
# dtype: float64

# %%
sd.std()
# Out:
# Height in cms    8.396428
# Weight in kgs    4.835057
# dtype: float64

# %%
#Handling Missing data
sd
# Out:
#    Height in cms  Weight in kgs Athlete
# 0          165.0           65.0     yes
# 1          160.0           70.0      no
# 2          140.0           55.0      no
# 3          156.0           59.0      no
# 4          162.0           62.0     yes
# 5          162.0           62.0     yes
# 6          170.0           65.0     yes
# 7          158.0           56.0     yes
# 8          150.0           68.0      no
# 9          162.0           62.0     NaN

# %%
sd.dropna()
# Out:
#    Height in cms  Weight in kgs Athlete
# 0          165.0           65.0     yes
# 1          160.0           70.0      no
# 2          140.0           55.0      no
# 3          156.0           59.0      no
# 4          162.0           62.0     yes
# 5          162.0           62.0     yes
# 6          170.0           65.0     yes
# 7          158.0           56.0     yes
# 8          150.0           68.0      no

# %%
sd
# Out:
#    Height in cms  Weight in kgs Athlete
# 0          165.0           65.0     yes
# 1          160.0           70.0      no
# 2          140.0           55.0      no
# 3          156.0           59.0      no
# 4          162.0           62.0     yes
# 5          162.0           62.0     yes
# 6          170.0           65.0     yes
# 7          158.0           56.0     yes
# 8          150.0           68.0      no
# 9          162.0           62.0     NaN

# %%
sd.fillna('yes')
# Out:
#    Height in cms  Weight in kgs Athlete
# 0          165.0           65.0     yes
# 1          160.0           70.0      no
# 2          140.0           55.0      no
# 3          156.0           59.0      no
# 4          162.0           62.0     yes
# 5          162.0           62.0     yes
# 6          170.0           65.0     yes
# 7          158.0           56.0     yes
# 8          150.0           68.0      no
# 9          162.0           62.0     yes

# %%
#plotting data
import matplotlib
sd.plot.hist()

# %%
sd.plot.scatter(x='Height in cms',y= 'Weight in kgs')

# %%
sd.expanding()
# Out:
# Expanding [min_periods=1,center=False,axis=0]

# %%
sd.rolling(5)
# Out:
# Rolling [window=5,center=False,axis=0]

# %%
sd
# Out:
#    Height in cms  Weight in kgs Athlete
# 0          165.0           65.0     yes
# 1          160.0           70.0      no
# 2          140.0           55.0      no
# 3          156.0           59.0      no
# 4          162.0           62.0     yes
# 5          162.0           62.0     yes
# 6          170.0           65.0     yes
# 7          158.0           56.0     yes
# 8          150.0           68.0      no
# 9          162.0           62.0     NaN

# %%
sd.groupby(by= "Athlete")

# %%
#read group by commands from other reference

# %%
#make new columns

# %%
#rename a column
sd = sd.rename(columns = {"Height in cms":"Height", "Weight in kgs":"Weight"})

# %%
sd
# Out:
#    Height  Weight Athlete
# 0   165.0    65.0     yes
# 1   160.0    70.0      no
# 2   140.0    55.0      no
# 3   156.0    59.0      no
# 4   162.0    62.0     yes
# 5   162.0    62.0     yes
# 6   170.0    65.0     yes
# 7   158.0    56.0     yes
# 8   150.0    68.0      no
# 9   162.0    62.0     NaN

# %%
sd.assign(HW = lambda sd:sd.Height *sd.Weight)
# Out:
#    Height  Weight Athlete       HW
# 0   165.0    65.0     yes  10725.0
# 1   160.0    70.0      no  11200.0
# 2   140.0    55.0      no   7700.0
# 3   156.0    59.0      no   9204.0
# 4   162.0    62.0     yes  10044.0
# 5   162.0    62.0     yes  10044.0
# 6   170.0    65.0     yes  11050.0
# 7   158.0    56.0     yes   8848.0
# 8   150.0    68.0      no  10200.0
# 9   162.0    62.0     NaN  10044.0

# %%
sd['HWW'] = sd.Height * sd.Weight * sd.Weight

# %%
sd
# Out:
#    Height  Weight Athlete       HWW
# 0   165.0    65.0     yes  697125.0
# 1   160.0    70.0      no  784000.0
# 2   140.0    55.0      no  423500.0
# 3   156.0    59.0      no  543036.0
# 4   162.0    62.0     yes  622728.0
# 5   162.0    62.0     yes  622728.0
# 6   170.0    65.0     yes  718250.0
# 7   158.0    56.0     yes  495488.0
# 8   150.0    68.0      no  693600.0
# 9   162.0    62.0     NaN  622728.0

# %%
sd
# Out:
#    Height  Weight Athlete       HWW
# 0   165.0    65.0     yes  697125.0
# 1   160.0    70.0      no  784000.0
# 2   140.0    55.0      no  423500.0
# 3   156.0    59.0      no  543036.0
# 4   162.0    62.0     yes  622728.0
# 5   162.0    62.0     yes  622728.0
# 6   170.0    65.0     yes  718250.0
# 7   158.0    56.0     yes  495488.0
# 8   150.0    68.0      no  693600.0
# 9   162.0    62.0     NaN  622728.0

# %%
pd.qcut(sd.Height,5, labels=False) # not clear, seek different reference
# Out:
# 0    4
# 1    2
# 2    0
# 3    1
# 4    2
# 5    2
# 6    4
# 7    1
# 8    0
# 9    2
# Name: Height, dtype: int64

# %%
adf = pd.DataFrame({"x1":['A','B','C'], "x2":[1,2,3]})

# %%
adf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
bdf = pd.DataFrame({"x1":['A','B','D'], "x3":['T','F','T']})

# %%
bdf
# Out:
#   x1 x3
# 0  A  T
# 1  B  F
# 2  D  T

# %%
#combine data sets

# %%
pd.merge(adf,bdf, how ='left', on='x1')
# Out:
#   x1  x2   x3
# 0  A   1    T
# 1  B   2    F
# 2  C   3  NaN

# %%
pd.merge(adf,bdf,how='right', on='x1')
# Out:
#   x1   x2 x3
# 0  A  1.0  T
# 1  B  2.0  F
# 2  D  NaN  T

# %%
pd.merge(adf,bdf, how = 'inner', on='x1')
# Out:
#   x1  x2 x3
# 0  A   1  T
# 1  B   2  F

# %%
pd.merge(adf, bdf, how='outer',on = 'x1')
# Out:
#   x1   x2   x3
# 0  A  1.0    T
# 1  B  2.0    F
# 2  C  3.0  NaN
# 3  D  NaN    T

# %%
#filtering joins

# %%
adf[adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 0  A   1
# 1  B   2

# %%
adf[~adf.x1.isin(bdf.x1)]
# Out:
#   x1  x2
# 2  C   3

# %%
#create 2 more dataframe

# %%
ydf = pd.DataFrame({"x1":['A','B','C'], "x2":[1,2,3]})

# %%
ydf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
zdf = pd.DataFrame({"x1":['B','C','D'], "x2":[2,3,4]})

# %%
zdf
# Out:
#   x1  x2
# 0  B   2
# 1  C   3
# 2  D   4

# %%
pd.merge(ydf,zdf)
# Out:
#   x1  x2
# 0  B   2
# 1  C   3

# %%
pd.merge(ydf, zdf, how = 'outer')
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3
# 3  D   4

# %%
pd.merge(ydf, zdf, how='outer', indicator= 'True')
# Out:
#   x1  x2        True
# 0  A   1   left_only
# 1  B   2        both
# 2  C   3        both
# 3  D   4  right_only
